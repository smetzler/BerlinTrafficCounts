# %%
from os import listdir
import pandas as pd

dir_path= r"Rohdaten_Berlin_1992-2019"
files = listdir(dir_path)
len(files)
# Out:
# 20810

# %%
#count=False
#row=0
from tqdm import tqdm

df_dict={}
for indexf,f in tqdm(enumerate(files)): #(files[:500]):
    with open(dir_path+'\\'+f, encoding='ISO-8859-1',errors='ignore') as fi:
    #with open(dir_path+'\\'+f, encoding='utf-8') as fi:

        content = fi.readlines()

    content = [x.strip() for x in content]
    #print (indexf)
    

    ind={}
    for index,c in enumerate(content):
    
        
        
        #### HEADER ####
        if 'knoten='  in c: 
            knoten= c.replace('knoten=','')
            #df = df.append([{'filename':f[:-4]}],  ignore_index=True)
                        
        if 'bez='  in c: 
            bez= c.replace('bez=','')

        if 'datum='  in c: 
            datum= c.replace('datum=','')
            
        if 'zeit='  in c: 
            zeit= c.replace('zeit=','')
            
            zeit1=int(zeit[:2])
            zeit2=int(zeit[5:7])
            
            #print (zeit2-zeit1)
        if 'kurzken='  in c: 
            kurzken= c.replace('kurzken=','')
            #df.iloc[indexf, df.columns.get_loc('kurzken')] = kurzken
            #print (kurzken)
        if 'art='  in c: 
            art= c.replace('art=','')
            #art_len=len(art.split(','))
        if 'arm1='  in c: 
            arm1= c.replace('arm1=','')
        if 'arm2='  in c: 
            arm2= c.replace('arm2=','')
        if 'arm3='  in c: 
            arm3= c.replace('arm3=','')
        if 'arm4='  in c: 
            arm4= c.replace('arm4=','')
            
        if 'data='in c:
            #df = df.append([{'filename':f[:-4], 'knoten':knoten, 'bez':bez, 'datum':datum, 'kurzken':kurzken,
            #         'zeit':zeit, 'art':art, 'art_len':art_len}])
            df_dict[indexf]={'filename':f[:-4], 'knoten':knoten, 'bez':bez, 'datum':datum, 'kurzken':kurzken,
                     'zeit':zeit, 'art':art, 'arm1':arm1, 'arm2':arm2, 'arm3':arm3, 'arm4':arm4}#, 'art_len':art_len}
            

 

    
df= pd.DataFrame.from_dict(df_dict, orient='index')
    
df
# Out:
# 20810it [00:05, 3801.22it/s]
#                 filename     knoten  \
# 0               000013H8     K 0001
# 1               0000230U     K 0002
# 2               000023ML     K 0002
# 3               0000730U     K 0007
# 4               000073MD     K 0007
# 5               0000830U     K 0008
# 6               000083MD     K 0008
# 7               000093MD     K 0009
# 8               0000A3MD     K 0010
# 9               0000E30U     K 0014
# 10              0000J30U     K 0019
# 11              0000M209     K 0022
# 12              0000N30U     K 0023
# 13              0000O217     K 0024
# 14              0000O3L0     K 0024
# 15              0000O4M9       K 24
# 16              0000U26Y     K 0030
# 17              0000V26Y     K 0031
# 18              0000V2LR     K 0031
# 19              0000V2OI     K 0031
# 20              0000W2IX     K 0032
# 21              0000W2NF     K 0032
# 22              0000Y30U     K 0034
# 23              0000Z2IW     K 0035
# 24              000102IW     K 0036
# 25              000102NF     K 0036
# 26              000121CR     K 0038
# 27              000122IW     K 0038
# 28              000122NF     K 0038
# 29              000141OW     K 0040
# ...                  ...        ...
# 20780  Q7531014_20070524  Q 7531014
# 20781  Q7535021_20190606   Q7535021
# 20782  Q7535022_20190606   Q7535022
# 20783  Q7535023_20190606   Q7535023
# 20784  Q7535024_20190606   Q7535024
# 20785  Q7536021_20060327  Q 7536021
# 20786  Q7536022_20060327  Q 7536022
# 20787  Q7536023_20060327  Q 7536023
# 20788  Q7614025_19950328  Q 7614025
# 20789  Q7614025_19950601  Q 7614025
# 20790  Q7614026_19950328  Q 7614026
# 20791  Q7614026_19950601  Q 7614026
# 20792  Q7614028_19950328  Q 7614028
# 20793  Q7614028_19950601  Q 7614028
# 20794  Q7631021_20100316  Q 7631021
# 20795  Q7631022_20100316  Q 7631022
# 20796  Q7631023_20100316  Q 7631023
# 20797  Q7631024_20100316  Q 7631024
# 20798  Q7631025_20100316  Q 7631025
# 20799  Q8248015_19960916  Q 8248015
# 20800  Q8248017_19960916  Q 8248017
# 20801  Q8318012_20020923  Q 8318012
# 20802  Q8318012_20080130  Q 8318012
# 20803  Q8318013_20020923  Q 8318013
# 20804  Q8318013_20080130  Q 8318013
# 20805  Q8318014_20020923  Q 8318014
# 20806  Q8318014_20080130  Q 8318014
# 20807  Q9100131_19981103  Q 9100131
# 20808  Q9100132_19981103  Q 9100132
# 20809  Q9100133_19981103  Q 9100133
#
#                                                      bez       datum  \
# 0      Oranienburger Chaussee / Hubertusweg - Staehle...  29.11.1990
# 1      Oranienburger Chaussee / Zeltinger Strasse - R...  15.06.1989
# 2      Oranienburger Chaussee / Zeltinger Strasse - R...  30.04.1991
# 3      Zeltinger Platz / Frohnauer Bruecke    ( Berli...  15.06.1989
# 4            Zeltinger Platz / Bruecke     ( Berlin 28 )  22.04.1991
# 5      Zeltinger Platz / Burgfrauenstrasse    ( Berli...  15.06.1989
# 6      Zeltinger Platz / Burgfrauenstrasse    ( Berli...  22.04.1991
# 7         Zeltinger Platz / Edelhofdamm    ( Berlin 28 )  22.04.1991
# 8      Zeltinger Platz / Wiltinger Strasse    ( Berli...  22.04.1991
# 9        Am Eichenhain / Sigismundkorso    ( Berlin 28 )  15.06.1989
# 10     Ludolfingerplatz / Sigismundkorso    ( Berlin ...  15.06.1989
# 11     Burgfrauenstrasse / Hohefeldstrasse   ( Berlin...  10.04.1986
# 12     Berliner Strasse / Hermsdorfer Damm    ( Berli...  15.06.1989
# 13     Ruppiner Chaussee / Kiefheider Weg    ( Berlin...  12.05.1986
# 14     Ruppiner Chaussee / Kiefheider Weg    ( Berlin...  05.03.1991
# 15     Ruppiner Chaussee / Kiefheider Weg (Reinickend...  02.06.1994
# 16     Alt-Heiligensee - Schulzend. Str. / Hennigsd. ...  27.11.1986
# 17     Ruppiner Chaussee / Schulzendorfer Strasse - B...  27.11.1986
# 18     Ruppiner Chaussee / Schulzendorfer Strasse - B...  16.02.1988
# 19     Ruppiner Chaussee / Schulzendorfer Strasse - B...  19.05.1988
# 20     Hermsdorfer Damm / Frohnauer Strasse      ( Be...  10.12.1987
# 21     Hermsdorfer Damm / Frohnauer Strasse   ( Berli...  12.04.1988
# 22        Berliner Strasse / Robinenweg    ( Berlin 28 )  15.06.1989
# 23     Tegeler Strasse / Ulmenstrasse      ( Berlin 28 )  09.12.1987
# 24       Tegeler Strasse / Robinienweg     ( Berlin 28 )  09.12.1987
# 25         Tegeler Strasse / Robinienweg   ( Berlin 28 )  12.04.1988
# 26     Schulzendorfer Strasse / Hermsdorfer Damm   ( ...  28.03.1984
# 27     Hermsdorfer Damm / Schulzendorfer Strasse    (...  09.12.1987
# 28     Hermsdorfer Damm / Schulzendorfer Strasse   ( ...  12.04.1988
# 29     Oraniendamm / Waidmannsluster Damm - Zabel-Kru...  17.04.1985
# ...                                                  ...         ...
# 20780  Blumberger Damm (nördl. Alt-Biesdorf)   (Biesd...  24.05.2007
# 20781  Blumberger Damm / Cecilienstraße (Hellersdorf,...  06.06.2019
# 20782  Blumberger Damm / Cecilienstraße (Hellersdorf,...  06.06.2019
# 20783  Blumberger Damm / Cecilienstraße (Hellersdorf,...  06.06.2019
# 20784  Blumberger Damm / Cecilienstraße (Hellersdorf,...  06.06.2019
# 20785  Elisabethstraße (westl. Oberfeldstraße)   (Bie...  27.03.2006
# 20786  Oberfeldstraße (südl. Elisabethstraße)   (Bies...  27.03.2006
# 20787  Elisabethstraße (östl. Oberfeldstraße)   (Bies...  27.03.2006
# 20788  Dorfstr. (westl. Hohenschönhauser Str.)     (F...  28.03.1995
# 20789  Dorfstr. (westl. Hohenschönhauser Str.), (Falk...  01.06.1995
# 20790  Hohenschönhauser Str. (südl. Dorfstraße) (Falk...  28.03.1995
# 20791  Hohenschönhauser Str. (südl. Dorfstraße),(Falk...  01.06.1995
# 20792  Ahrensfelder Straße (nördl. Dorfstraße) (Falke...  28.03.1995
# 20793  Ahrensfelder Straße (nördl. Dorfstraße), (Falk...  01.06.1995
# 20794  Raoul-Wallenberg-Str. (westl.. J.-Petersen-Str...  16.03.2010
# 20795  Zufahrt Wohngebiet (südl. Raoul-Wallenberg-Str...  16.03.2010
# 20796  Raoul-Wallenberg-Straße (östl. Jan-Petersen-St...  16.03.2010
# 20797  Jan-Petersen-Straße (nördl. Raoul-Wallenberg-S...  16.03.2010
# 20798  Raoul-Wallenberg-Str. (westl. J.-Petersen-Str....  16.03.2010
# 20799  Alt-Müggelheim  (westl. Krampenburger Weg)    ...  16.09.1996
# 20800  Gosener Damm  (östl. Krampenburger Weg)    (Mü...  16.09.1996
# 20801  Bölschestraße (südl. Schöneicher Straße)  (Fri...  23.09.2002
# 20802  Bölschestraße (südl. Schöneicher Straße)  (Fri...  30.01.2008
# 20803  Schöneicher Straße (östl. Dahlwitzer Landstr.)...  23.09.2002
# 20804  Schöneicher Straße (östl. Dahlwitzer Landstr.)...  30.01.2008
# 20805  Dahlwitzer Landstr. (nördl. Schöneicher Straße...  23.09.2002
# 20806  Dahlwitzer Landstr. (nördl. Schöneicher Straße...  30.01.2008
# 20807  Potsdamer Ch. (östl. Nibelungenstr., jew. link...  03.11.1998
# 20808  Potsdamer Ch. (östl. Nibelungenstr. - jew. mit...  03.11.1998
# 20809  Potsdamer Ch. (östl. Nibelungenstr., jew. rech...  03.11.1998
#
#             kurzken       zeit                            art  \
# 0            K 1/90  0700,1900        Krad,Pkw,Liefwg,Lkw,Bus
# 1            K 2/89  0700,1900                      Kfz,,,,,,
# 2            K 2/91  0700,1900      Krad,Pkw,Liefwg,Lkw,Bus,,
# 3            K 7/89  0700,1900                      Kfz,,,,,,
# 4            K 7/91  0700,1900      Krad,Pkw,Liefwg,Lkw,Bus,,
# 5            K 8/89  0700,1900                      Kfz,,,,,,
# 6            K 8/91  0700,1900      Krad,Pkw,Liefwg,Lkw,Bus,,
# 7            K 9/91  0700,1900        Krad,Pkw,Liefwg,Lkw,Bus
# 8           K 10/91  0700,1900      Krad,Pkw,Liefwg,Lkw,Bus,,
# 9           K 14/89  0700,1900                      Kfz,,,,,,
# 10          K 19/89  0700,1900                            Kfz
# 11          K 22/86  0700,1900      Krad,Pkw,Liefwg,Lkw,Bus,,
# 12          K 23/89  0700,1900                      Kfz,,,,,,
# 13          K 24/86  0700,1900      Krad,Pkw,Liefwg,Lkw,Bus,,
# 14          K 24/91  0700,1900  Krad,Pkw,Liefwg,Lkw,Bus,Radf,
# 15          K 24/94  0700,1900      Pkw+Lfw,Lkw,Bus,Krad,Radf
# 16          K 30/86  0700,1900      Krad,Pkw,Liefwg,Lkw,Bus,,
# 17          K 31/86  0700,1900      Krad,Pkw,Liefwg,Lkw,Bus,,
# 18          K 31/88  0700,1900                      Kfz,,,,,,
# 19          K 31/88  0700,1900      Krad,Pkw,Liefwg,Lkw,Bus,,
# 20          K 32/87  0700,1900                      Kfz,,,,,,
# 21          K 32/88  0700,1900                      Kfz,,,,,,
# 22          K 34/89  0700,1900                      Kfz,,,,,,
# 23          K 35/87  0700,1900                      Kfz,,,,,,
# 24          K 36/87  0700,1900                      Kfz,,,,,,
# 25          K 36/88  0700,1900                      Kfz,,,,,,
# 26          K 38/84  0700,1900      Krad,Pkw,Liefwg,Lkw,Bus,,
# 27          K 38/87  0700,1900                      Kfz,,,,,,
# 28          K 38/88  0700,1900                      Kfz,,,,,,
# 29          K 40/85  0700,1900      Krad,Pkw,Liefwg,Lkw,Bus,,
# ...             ...        ...                            ...
# 20780  Q 7531014/07  0700,1900                     Erw,Jugend
# 20781   Q7535021/19  0700,1900                     Erw,Jugend
# 20782   Q7535022/19  0700,1900                     Erw,Jugend
# 20783   Q7535023/19  0700,1900                     Erw,Jugend
# 20784   Q7535024/19  0700,1900                     Erw,Jugend
# 20785  Q 7536021/06  0700,1900                     Erw,Jugend
# 20786  Q 7536022/06  0700,1900                     Erw,Jugend
# 20787  Q 7536023/06  0700,1900                     Erw,Jugend
# 20788  Q 7614025/95  0700,1900                     Erw,Jugend
# 20789  Q 7614025/95  0700,1900                     Erw,Jugend
# 20790  Q 7614026/95  0700,1900                     Erw,Jugend
# 20791  Q 7614026/95  0700,1900                     Erw,Jugend
# 20792  Q 7614028/95  0700,1900                     Erw,Jugend
# 20793  Q 7614028/95  0700,1900                     Erw,Jugend
# 20794  Q 7631021/10  0700,1900                     Erw,Jugend
# 20795  Q 7631022/10  0700,1900                     Erw,Jugend
# 20796  Q 7631023/10  0700,1900                     Erw,Jugend
# 20797  Q 7631024/10  0700,1900                     Erw,Jugend
# 20798  Q 7631025/10  0700,1900                     Erw,Jugend
# 20799  Q 8248015/96  0700,1900                     Erw,Jugend
# 20800  Q 8248017/96  0700,1900                     Erw,Jugend
# 20801  Q 8318012/02  0700,1900                     Erw,Jugend
# 20802  Q 8318012/08  0700,1900                     Erw,Jugend
# 20803  Q 8318013/02  0700,1900                     Erw,Jugend
# 20804  Q 8318013/08  0700,1900                     Erw,Jugend
# 20805  Q 8318014/02  0700,1900                     Erw,Jugend
# 20806  Q 8318014/08  0700,1900                     Erw,Jugend
# 20807  Q 9100131/98  1200,1800           Pkw+Lfw,Lkw,Bus,Krad
# 20808  Q 9100132/98  1200,1800           Pkw+Lfw,Lkw,Bus,Krad
# 20809  Q 9100133/98  1200,1800           Pkw+Lfw,Lkw,Bus,Krad
#
#                                    arm1                             arm2  \
# 0            Oranienburger Ch.,240,0111              Staehleweg,980,1011
# 1            Oranienburger Ch.,240,0111              Staehleweg,980,1011
# 2            Oranienburger Ch.,240,0111              Staehleweg,980,1011
# 3            Oranienburger Ch.,240,0111              Staehleweg,980,1011
# 4            Oranienburger Ch.,240,0111              Staehleweg,980,1011
# 5            Oranienburger Ch.,240,0111              Staehleweg,980,1011
# 6            Oranienburger Ch.,240,0111              Staehleweg,980,1011
# 7              Zeltinger Platz,300,0000                          ,0,0000
# 8              Zeltinger Platz,300,0000                          ,0,0000
# 9              Zeltinger Platz,300,0000                          ,0,0000
# 10                              ,0,0000         Sigismundkorso,1250,0010
# 11                              ,0,0000         Sigismundkorso,1250,0010
# 12                              ,0,0000         Sigismundkorso,1250,0010
# 13                              ,0,0000         Sigismundkorso,1250,0010
# 14                              ,0,0000         Sigismundkorso,1250,0010
# 15           Ruppiner Chaussee,500,0011                          ,0,0000
# 16           Ruppiner Chaussee,500,0011                          ,0,0000
# 17           Ruppiner Chaussee,500,0011                          ,0,0000
# 18           Ruppiner Chaussee,500,0011                          ,0,0000
# 19           Ruppiner Chaussee,500,0011                          ,0,0000
# 20           Ruppiner Chaussee,500,0011                          ,0,0000
# 21           Ruppiner Chaussee,500,0011                          ,0,0000
# 22           Ruppiner Chaussee,500,0011                          ,0,0000
# 23           Ruppiner Chaussee,500,0011                          ,0,0000
# 24           Ruppiner Chaussee,500,0011                          ,0,0000
# 25           Ruppiner Chaussee,500,0011                          ,0,0000
# 26           Ruppiner Chaussee,500,0011                          ,0,0000
# 27           Ruppiner Chaussee,500,0011                          ,0,0000
# 28           Ruppiner Chaussee,500,0011                          ,0,0000
# 29           Ruppiner Chaussee,500,0011                          ,0,0000
# ...                                 ...                              ...
# 20780             Alt-Biesdorf,830,0010      Köpenicker Straße,1800,0000
# 20781      Blumberger Damm (N),120,0000      Cecilienstraße (W),850,0001
# 20782      Blumberger Damm (N),120,0010      Cecilienstraße (W),850,0000
# 20783      Blumberger Damm (N),120,0000      Cecilienstraße (W),850,0001
# 20784      Blumberger Damm (N),120,0010      Cecilienstraße (W),850,0000
# 20785          Elisabethstraße,940,0000         Oberfeldstraße,1600,0001
# 20786          Elisabethstraße,940,0010         Oberfeldstraße,1600,0000
# 20787          Elisabethstraße,940,0000         Oberfeldstraße,1600,0001
# 20788               Dorfstraße,640,0000  Hohenschönhauser Str.,1440,0001
# 20789               Dorfstraße,640,0000              Südwesten,1440,0001
# 20790               Dorfstraße,640,0010   Hohenschönhauser Str,1440,0000
# 20791               Nordwesten,640,0010   Hohenschönhauser Str,1440,0000
# 20792               Dorfstraße,640,0010   Hohenschönhauser Str,1440,0000
# 20793               Dorfstraße,640,0010  Hohenschönhauser Str.,1440,0000
# 20794  Raoul-Wallenberg-Straße,740,0000     Zufahrt Wohngebiet,1500,0001
# 20795  Raoul-Wallenberg-Straße,740,0010     Zufahrt Wohngebiet,1500,0000
# 20796  Raoul-Wallenberg-Straße,740,0000     Zufahrt Wohngebiet,1500,0001
# 20797  Raoul-Wallenberg-Straße,740,0010     Zufahrt Wohngebiet,1500,0000
# 20798  Raoul-Wallenberg-Straße,740,0000     Zufahrt Wohngebiet,1500,0001
# 20799                         ,420,0000      Krampenburger Weg,1370,0001
# 20800                         ,420,0000      Krampenburger Weg,1370,0001
# 20801                     West,900,0010          Bölschestraße,1800,0000
# 20802               ((Westen)),900,0010          Bölschestraße,1800,0000
# 20803                           ,0,0000                    Süd,1800,0001
# 20804                           ,0,0000          Bölschestraße,1800,0001
# 20805                     West,900,0010          Bölschestraße,1800,0000
# 20806               ((Westen)),900,0010          Bölschestraße,1800,0000
# 20807         Nibelungenstraße,950,0100           Isoldestraße,2750,1000
# 20808         Nibelungenstraße,950,0100           Isoldestraße,2750,1000
# 20809         Nibelungenstraße,950,0100           Isoldestraße,2750,1000
#
#                                     arm3                           arm4
# 0            Oranienburger Ch.,2040,1101          Hubertusweg,2780,1110
# 1            Oranienburger Ch.,2040,1101          Hubertusweg,2780,1110
# 2            Oranienburger Ch.,2040,1101          Hubertusweg,2780,1110
# 3            Oranienburger Ch.,2040,1101          Hubertusweg,2780,1110
# 4            Oranienburger Ch.,2040,1101          Hubertusweg,2780,1110
# 5            Oranienburger Ch.,2040,1101          Hubertusweg,2780,1110
# 6            Oranienburger Ch.,2040,1101          Hubertusweg,2780,1110
# 7              Zeltinger Platz,1700,1001          Edelhofdamm,2750,1000
# 8              Zeltinger Platz,1700,1001          Edelhofdamm,2750,1000
# 9              Zeltinger Platz,1700,1001          Edelhofdamm,2750,1000
# 10            Ludolfingerplatz,2450,0000     Ludolfingerplatz,3050,0110
# 11            Ludolfingerplatz,2450,0000     Ludolfingerplatz,3050,0110
# 12            Ludolfingerplatz,2450,0000     Ludolfingerplatz,3050,0110
# 13            Ludolfingerplatz,2450,0000     Ludolfingerplatz,3050,0110
# 14            Ludolfingerplatz,2450,0000     Ludolfingerplatz,3050,0110
# 15           Ruppiner Chaussee,2150,1001       Kiefheider Weg,3100,1010
# 16           Ruppiner Chaussee,2150,1001       Kiefheider Weg,3100,1010
# 17           Ruppiner Chaussee,2150,1001       Kiefheider Weg,3100,1010
# 18           Ruppiner Chaussee,2150,1001       Kiefheider Weg,3100,1010
# 19           Ruppiner Chaussee,2150,1001       Kiefheider Weg,3100,1010
# 20           Ruppiner Chaussee,2150,1001       Kiefheider Weg,3100,1010
# 21           Ruppiner Chaussee,2150,1001       Kiefheider Weg,3100,1010
# 22           Ruppiner Chaussee,2150,1001       Kiefheider Weg,3100,1010
# 23           Ruppiner Chaussee,2150,1001       Kiefheider Weg,3100,1010
# 24           Ruppiner Chaussee,2150,1001       Kiefheider Weg,3100,1010
# 25           Ruppiner Chaussee,2150,1001       Kiefheider Weg,3100,1010
# 26           Ruppiner Chaussee,2150,1001       Kiefheider Weg,3100,1010
# 27           Ruppiner Chaussee,2150,1001       Kiefheider Weg,3100,1010
# 28           Ruppiner Chaussee,2150,1001       Kiefheider Weg,3100,1010
# 29           Ruppiner Chaussee,2150,1001       Kiefheider Weg,3100,1010
# ...                                  ...                            ...
# 20780             Alt-Biesdorf,2380,1000      Blumberger Damm,3550,0000
# 20781      Blumberger Damm (S),1780,0000   Cecilienstraße (O),2740,0100
# 20782      Blumberger Damm (S),1780,1000   Cecilienstraße (O),2740,0000
# 20783      Blumberger Damm (S),1780,0000   Cecilienstraße (O),2740,0100
# 20784      Blumberger Damm (S),1780,1000   Cecilienstraße (O),2740,0000
# 20785          Elisabethstraße,2740,0000           ((Norden)),3400,0100
# 20786          Elisabethstraße,2740,1000                     ,3400,0000
# 20787          Elisabethstraße,2740,0000           ((Norden)),3400,0100
# 20788                    Osten,2440,0000     Ahrensfelder Ch.,2920,0100
# 20789                    Osten,2440,0000            Nordosten,2920,0100
# 20790                    Osten,2440,1000     Ahrensfelder Ch.,2920,0000
# 20791                 Südosten,2440,1000     Ahrensfelder Ch.,2920,0000
# 20792                    Osten,2440,1000     Ahrensfelder Ch.,2920,0000
# 20793                    Osten,2440,1000     Ahrensfelder Ch.,2920,0000
# 20794  Raoul-Wallenberg-Straße,2350,0000  Jan-Petersen-Straße,3300,0100
# 20795  Raoul-Wallenberg-Straße,2350,1000  Jan-Petersen-Straße,3300,0000
# 20796  Raoul-Wallenberg-Straße,2350,0000  Jan-Petersen-Straße,3300,0100
# 20797  Raoul-Wallenberg-Straße,2350,1000  Jan-Petersen-Straße,3300,0000
# 20798  Raoul-Wallenberg-Straße,2350,0000  Jan-Petersen-Straße,3300,0100
# 20799                         ,2220,0000      Geinsheimer Weg,3160,0100
# 20800                         ,2220,0000      Geinsheimer Weg,3160,0100
# 20801                      Ost,2650,1000  Dahlwitzer Landstr.,3510,0000
# 20802       Schöneicher Straße,2650,1000  Dahlwitzer Landstr.,3510,0000
# 20803       Schöneicher Straße,2650,0000                 Nord,3510,0100
# 20804       Schöneicher Straße,2650,0000  Dahlwitzer Landstr.,3510,0100
# 20805                      Ost,2650,1000  Dahlwitzer Landstr.,3510,0000
# 20806       Schöneicher Straße,2650,1000  Dahlwitzer Landstr.,3510,0000
# 20807                            ,0,0000                        ,0,0000
# 20808                            ,0,0000                        ,0,0000
# 20809                            ,0,0000                        ,0,0000
#
# [20697 rows x 11 columns]

# %%
#df.bez=df.bez.apply(lambda x: x.replace('\x96','').replace('\x93','').replace('ß','ss').replace('ä','ae').replace('ö','oe').replace('ü','ue').replace('Ä','Ae').replace('Ö','Oe').replace('Ü','Ue'))

# %%
for col in ['bez','arm1','arm2','arm3','arm4']:
    df[col]=df[col].apply(lambda x: x.replace('\x96','').replace('\x93','').replace('ß','ss').replace('ä','ae').replace('ö','oe').replace('ü','ue').replace('Ä','Ae').replace('Ö','Oe').replace('Ü','Ue'))

# %%
df.datum= pd.to_datetime(df.datum)#, format='%d%b

# %%
pd.set_option('display.max_colwidth', -1)
df.head()
# Out:
#    filename  knoten  \
# 0  000013H8  K 0001
# 1  0000230U  K 0002
# 2  000023ML  K 0002
# 3  0000730U  K 0007
# 4  000073MD  K 0007
#
#                                                                                 bez  \
# 0  Oranienburger Chaussee / Hubertusweg - Staehleweg   ( Berlin 28 )
# 1  Oranienburger Chaussee / Zeltinger Strasse - Rauentaler Strasse    ( Berlin 28 )
# 2  Oranienburger Chaussee / Zeltinger Strasse - Rauentaler Strasse   ( Berlin 28 )
# 3  Zeltinger Platz / Frohnauer Bruecke    ( Berlin 28 )
# 4  Zeltinger Platz / Bruecke     ( Berlin 28 )
#
#        datum kurzken       zeit                        art  \
# 0 1990-11-29  K 1/90  0700,1900  Krad,Pkw,Liefwg,Lkw,Bus
# 1 1989-06-15  K 2/89  0700,1900  Kfz,,,,,,
# 2 1991-04-30  K 2/91  0700,1900  Krad,Pkw,Liefwg,Lkw,Bus,,
# 3 1989-06-15  K 7/89  0700,1900  Kfz,,,,,,
# 4 1991-04-22  K 7/91  0700,1900  Krad,Pkw,Liefwg,Lkw,Bus,,
#
#                          arm1                 arm2  \
# 0  Oranienburger Ch.,240,0111  Staehleweg,980,1011
# 1  Oranienburger Ch.,240,0111  Staehleweg,980,1011
# 2  Oranienburger Ch.,240,0111  Staehleweg,980,1011
# 3  Oranienburger Ch.,240,0111  Staehleweg,980,1011
# 4  Oranienburger Ch.,240,0111  Staehleweg,980,1011
#
#                           arm3                   arm4
# 0  Oranienburger Ch.,2040,1101  Hubertusweg,2780,1110
# 1  Oranienburger Ch.,2040,1101  Hubertusweg,2780,1110
# 2  Oranienburger Ch.,2040,1101  Hubertusweg,2780,1110
# 3  Oranienburger Ch.,2040,1101  Hubertusweg,2780,1110
# 4  Oranienburger Ch.,2040,1101  Hubertusweg,2780,1110

# %%
#<a href="https://smetzler.github.io/pks_viz//table/pks2018krs_Straftateninsgesamt.html">Table</a>

# %%
df['file_link']=df['filename'].apply(lambda x: "href=Rohdaten_Berlin_1992-2019/"+x+ ".zda" if len(x)>10 else "href=Rohdaten_Berlin_1992-2019/"+x+ ".ZDA" )

# %%
#df['chart']=df['filename'].apply(lambda x: "href=html_charts/"+x+ ".html" if len(x)>10 else "")

# %%
df['chart']=''
for index, row in tqdm(df.iterrows()):
    art_list=row['art'].split(',')
    if (any("Pkw+Lfw" in s for s in art_list) or (any("Radf" in s for s in art_list))):
        #row['chart']= "href=html_charts/" + row['filename']+ ".html"
        df.at[index,'chart'] = "href=html_charts/" + row['filename']+ ".html"
        #print (row['chart'])
# Out:
# 20697it [00:03, 6288.82it/s]

# %%
len(df)
# Out:
# 20697

# %%
len(df[df.chart!=''])
# Out:
# 14229

# %%
df.dtypes
# Out:
# filename     object
# knoten       object
# bez          object
# datum        datetime64[ns]
# kurzken      object
# zeit         object
# art          object
# arm1         object
# arm2         object
# arm3         object
# arm4         object
# file_link    object
# chart        object
# dtype: object

# %%
df.sort_values('file_link').head()
# Out:
#    filename  knoten  \
# 0  000013H8  K 0001
# 1  0000230U  K 0002
# 2  000023ML  K 0002
# 3  0000730U  K 0007
# 4  000073MD  K 0007
#
#                                                                                 bez  \
# 0  Oranienburger Chaussee / Hubertusweg - Staehleweg   ( Berlin 28 )
# 1  Oranienburger Chaussee / Zeltinger Strasse - Rauentaler Strasse    ( Berlin 28 )
# 2  Oranienburger Chaussee / Zeltinger Strasse - Rauentaler Strasse   ( Berlin 28 )
# 3  Zeltinger Platz / Frohnauer Bruecke    ( Berlin 28 )
# 4  Zeltinger Platz / Bruecke     ( Berlin 28 )
#
#        datum kurzken       zeit                        art  \
# 0 1990-11-29  K 1/90  0700,1900  Krad,Pkw,Liefwg,Lkw,Bus
# 1 1989-06-15  K 2/89  0700,1900  Kfz,,,,,,
# 2 1991-04-30  K 2/91  0700,1900  Krad,Pkw,Liefwg,Lkw,Bus,,
# 3 1989-06-15  K 7/89  0700,1900  Kfz,,,,,,
# 4 1991-04-22  K 7/91  0700,1900  Krad,Pkw,Liefwg,Lkw,Bus,,
#
#                          arm1                 arm2  \
# 0  Oranienburger Ch.,240,0111  Staehleweg,980,1011
# 1  Oranienburger Ch.,240,0111  Staehleweg,980,1011
# 2  Oranienburger Ch.,240,0111  Staehleweg,980,1011
# 3  Oranienburger Ch.,240,0111  Staehleweg,980,1011
# 4  Oranienburger Ch.,240,0111  Staehleweg,980,1011
#
#                           arm3                   arm4  \
# 0  Oranienburger Ch.,2040,1101  Hubertusweg,2780,1110
# 1  Oranienburger Ch.,2040,1101  Hubertusweg,2780,1110
# 2  Oranienburger Ch.,2040,1101  Hubertusweg,2780,1110
# 3  Oranienburger Ch.,2040,1101  Hubertusweg,2780,1110
# 4  Oranienburger Ch.,2040,1101  Hubertusweg,2780,1110
#
#                                      file_link chart
# 0  href=Rohdaten_Berlin_1992-2019/000013H8.ZDA
# 1  href=Rohdaten_Berlin_1992-2019/0000230U.ZDA
# 2  href=Rohdaten_Berlin_1992-2019/000023ML.ZDA
# 3  href=Rohdaten_Berlin_1992-2019/0000730U.ZDA
# 4  href=Rohdaten_Berlin_1992-2019/000073MD.ZDA

# %%
df.file_link = df.file_link.astype(str)
df.chart = df.chart.astype(str)

# %%
df=df.dropna()#subset=['file_link'])

# %%
#path_data = 'Rohdaten_Berlin_1992-2019_alleMeta.csv'
#data= pd.read_csv(path_data, encoding="latin-1")

# %%
def createDataTableHtml(df, path, titlee):

    df.to_html(path,classes = 'table table-striped table-bordered" id = "table_id')#, "utf-8")
    
    enco='ISO-8859-1'

    from bs4 import BeautifulSoup as Soup

    with open(path, 'r', encoding=enco) as f:
        webpage = f.read()#.decode('utf-8')

    soup = Soup(webpage)


    
    table = soup.find('table')
    title = soup.new_tag('title')
    title.string = titlee
    table.insert_before(title)
    
    
    style = soup.new_tag('style')
    style.string = 'table {display: none}'
    table.insert_before(style)


    script = soup.new_tag('script')
    script['src'] = "https://code.jquery.com/jquery-3.3.1.js"
    script['type'] = "text/javascript"
    table.insert_before(script)

    script = soup.new_tag('script')
    script['src'] = "https://cdn.datatables.net/1.10.19/js/jquery.dataTables.js"
    script['type'] = "text/javascript"
    script['charset'] = "utf8"
    table.insert_before(script)
    
    script = soup.new_tag('script')
    script['src'] = "https://cdn.datatables.net/1.10.20/js/dataTables.bootstrap.min.js"
    script['type'] = "text/javascript"
    table.insert_before(script)
    
    
    
    link = soup.new_tag('link')
    link['rel'] = "stylesheet"
    link['href'] = "https://maxcdn.bootstrapcdn.com/bootstrap/3.3.7/css/bootstrap.min.css"
    link['type'] = "text/css"
    table.insert_before(link)
    
    link = soup.new_tag('link')
    link['rel'] = "stylesheet"
    link['href'] = "https://cdn.datatables.net/1.10.19/css/jquery.dataTables.min.css"
    link['type'] = "text/css"
    table.insert_before(link)

    script = soup.new_tag('script')
    script.string = """$(document).ready( function () {
        $("#table_id").DataTable();
        $("#table_id").show()
    } );"""
    table.insert_before(script)

    bod=soup.new_tag("body")
    bod['style'] = "width:75%;margin-left: auto;margin-right: auto;"
    soup.table.wrap(bod)
    #soup.p.wrap(soup.new_tag("div")

    #print (soup)
    
    #add links
    for ite in soup.find_all('td'):
        if ite.string is not None:
            if ite.string.startswith('href=Roh'):
                a = soup.new_tag('a')
                a['href']=ite.string[5:]
                a.string="Rohdaten"
                ite.string=''

                #ite.td.insert(a)
                ite.append(a)
                
    #add links to charts
    for ite in soup.find_all('td'):
        if ite.string is not None:
            if ite.string.startswith('href=html_chart'):
                a = soup.new_tag('a')
                a['href']=ite.string[5:]
                a.string="Chart"
                ite.string=''

                #ite.td.insert(a)
                ite.append(a)
            

    source = soup.new_tag('a')
    source.string="Quelle: Verkehrslenkung Berlin / Rohdaten Verkehrszählungen, licence: CC BY-SA 3.0 DE"
    source['href'] = "https://fragdenstaat.de/anfrage/kfz-verkehrszahldaten-aus-berlin/"
    table.insert_after(source)
    

    with open(path, "w", encoding=enco) as outf:
        outf.write(str(soup))


#createDataTableHtml(data_fil, "table\df_test_auto.html")

# %%
createDataTableHtml(df, 'index.html', 'Verkehrszaehldaten Berlin - counts table')
